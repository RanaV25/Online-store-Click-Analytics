# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# -----------------------------
# 1. Load all tables
# -----------------------------

products_df = pd.read_sql("SELECT * FROM products", engine)
categories_df = pd.read_sql("SELECT * FROM categories", engine)
click_events_df = pd.read_sql("SELECT * FROM click_events", engine)
cart_events_df = pd.read_sql("SELECT * FROM cart_events", engine)
carts_df = pd.read_sql("SELECT * FROM carts", engine)
cart_items_df = pd.read_sql("SELECT * FROM cart_items", engine)
order_intents_df = pd.read_sql("SELECT * FROM order_intents", engine)
search_queries_df = pd.read_sql("SELECT * FROM search_queries", engine)

for df in [
    products_df,
    click_events_df,
    cart_events_df,
    carts_df,
    cart_items_df,
    order_intents_df,
    search_queries_df,
]:
    for col in ["created_at", "updated_at", "added_at", "removed_at"]:
        if col in df.columns:
            df[col] = pd.to_datetime(df[col], errors="coerce")

print("Tables loaded:")
print("products:", products_df.shape)
print("click_events:", click_events_df.shape)
print("cart_events:", cart_events_df.shape)
print("carts:", carts_df.shape)
print("cart_items:", cart_items_df.shape)
print("orders:", order_intents_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 # -----------------------------
#       2 # 1. Load all tables
#       3 # -----------------------------
#       4
# ----> 5 products_df = pd.read_sql("SELECT * FROM products", engine)
#       6 categories_df = pd.read_sql("SELECT * FROM categories", engine)
#       7 click_events_df = pd.read_sql("SELECT * FROM click_events", engine)
#       8 cart_events_df = pd.read_sql("SELECT * FROM cart_events", engine)
#
# NameError: name 'engine' is not defined
